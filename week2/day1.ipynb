# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-cIjZ
# Google API Key exists and begins AQ
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the aspiring LLM engineer bring a ladder to their code review?
#
# Because they wanted to reach the next level of *model understanding*!

# %%
response = ollama.chat.completions.create(model="llama3.1", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the Long Short Memory (LLM) engineer's model go to therapy?
#
# Because it was struggling to " recall" its past mistakes and had a hard time "predicting" its future success. But with each iteration, it was getting better at optimizing its memory and preventing regression.
#
# Hope that made you LOL (and also gave you a moment of introspection about the trials and tribulations of developing an LLM model)!

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# Let S be the sample space of tossing two coins. The possible outcomes are:
# S = {(H, H), (H, T), (T, H), (T, T)}
# Each outcome has a probability of 1/4.
#
# Let A be the event "One of them is heads". This means at least one coin is heads.
# The outcomes that satisfy event A are:
# A = {(H, H), (H, T), (T, H)}
# The probability of event A, P(A) = 3/4 (since there are 3 favorable outcomes, each with probability 1/4).
#
# We are asked for the probability that "the other is tails", given that "one of them is heads".
# Let B be the event "the other is tails". This means that if we know one coin is heads, the second coin (the "other" one) is tails. This implies that there is exactly one head and exactly one tail among the two coins.
# The outcomes that satisfy event B are:
# B = {(H, T), (T, H)}
#
# We are looking for the conditional probability P(B | A), which is P(A and B) / P(A).
#
# Let's find the outcomes that satisfy both A and B (A intersect B):
# A intersect B means "at least one coin is heads AND exactly one head and exactly one tail".
# The outcomes that are in both A and B are:
# A intersect B = {(H, T), (T, H)}
#
# The probability of (A intersect B) is P({(H, T), (T, H)}) = 1/4 + 1/4 = 2/4 = 1/2.
#
# Now we can calculate P(B | A):
# P(B | A) = P(A intersect B) / P(A)
# P(B | A) = (1/2) / (3/4)
# P(B | A) = (1/2) * (4/3)
# P(B | A) = 4/6 = 2/3
#
# The final answer is $\boxed{2/3}$.

# %%
response = ollama.chat.completions.create(model="llama3.1", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 0.5

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Assume the two volumes are arranged in the usual way on a shelf: Volume 1 on the left, Volume 2 on the right, with their spines facing outward. Each volume has:
# - pages thickness: 2 cm (total of all pages in that volume)
# - two covers: front and back, each 2 mm thick
#
# When the books sit side by side, the order from left to right is:
# [Back cover of V1] – [Pages of V1] – [Front cover of V1] – gap between volumes – [Back cover of V2] – [Pages of V2] – [Front cover of V2]
#
# A worm starts at the first page of the first volume (i.e., at the very inner edge of V1’s front cover, where the pages begin) and gnaws to the last page of the second volume (i.e., at the very outer edge of V2’s back cover).
#
# Key distances:
# - Pages thickness of V1: 2 cm
# - Pages thickness of V2: 2 cm
# - Front cover thickness: 2 mm
# - Back cover thickness: 2 mm
# - The “gap” between the two volumes on the shelf is just the air between V1’s front cover and V2’s back cover; there is no page material there.
#
# Path of the worm:
# - From the first page of V1 to the inner surface of V1’s front cover is essentially a distance of 0 (the page edge starts right at the inner boundary of the front couple of pages). Practically, the worm traverses through V1’s pages, then through V1’s front cover, then through the gap between volumes (air), then through V2’s back cover, then through V2’s pages to the last page.
#
# Compute total gnawed distance:
# - Through V1 pages: 2 cm
# - Through V1 front cover: 2 mm
# - Through the gap between volumes: 0 (they’re just touching or very close; the problem implies the volumes are side by side with no material in the gap)
# - Through V2 back cover: 2 mm
# - Through V2 pages: 2 cm
#
# Total = 2 cm + 0.2 cm + 0.2 cm + 2 cm = 4.4 cm
#
# But check: the worm starts at first page of first volume and ends at last page of second volume, so it does not gnaw through the final outer cover of V2? It ends at the last page of V2, which is at the inner edge of the front cover of V2, not through the front cover. Wait, need to be precise:
#
# - For V2, “last page” is the page nearest to the outer front cover or inner? If volumes are on shelf with front facing outward, the pages of V2 are between its back cover (left side) and front cover (right side). The last page (toward the right) is adjacent to the front cover. So the worm ends at the last page, i.e., just before the front cover of V2, so it does not gnaw through V2’s front cover.
#
# Similarly, “first page of the first volume” is near the right side of V1, adjacent to the front cover of V1. So it starts at that edge, not requiring to gnaw through V1 back cover or anything.
#
# Thus the worm travels:
# - Through V1 pages: 2 cm (from first page edge to the other side of the pages)
# - Through V1 front cover: 2 mm
# - Through the gap between volumes: zero
# - Through V2 back cover: 2 mm
# - Through V2 pages: 2 cm to reach last page
#
# Total = 2 cm + 0.2 cm + 0.2 cm + 2 cm = 4.4 cm
#
# Answer: 4.4 centimeters.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# Let's analyze the problem carefully.
#
# ---
#
# ### Given:
# - Two volumes of Pushkin stand **side by side**: first and second.
# - The **pages of each volume**, combined, have a **thickness of 2 cm**.
# - Each **cover** (front or back) is **2 mm (0.2 cm)** thick.
# - The worm gnaws from the **first page of the first volume** to the **last page of the second volume**, gnawing **perpendicular to the pages**.
#
# ---
#
# ### Objective:
# Find the distance the worm gnawed through.
#
# ---
#
# ### Step 1: Understanding the physical setup
#
# - Each volume consists of:
#   - Front cover (2 mm = 0.2 cm thick)
#   - Pages (2.0 cm thick)
#   - Back cover (0.2 cm thick)
#
# - So total thickness of each volume:
#   \[
#   0.2 + 2.0 + 0.2 = 2.4 \text{ cm}
#   \]
#
# ---
#
# ### Step 2: How volumes are arranged
#
# Books on a shelf are **typically placed with front covers facing left** (for the first volume).
#
# The problem is tricky because the worm gnaws from the **first page of the first volume** to the **last page of the second volume**.
#
# Pages in books are always **between front and back covers**.
#
# So let's see where the first page of the first volume is, and where the last page of the second volume is.
#
# ---
#
# ### Step 3: Orientation of the two volumes side by side
#
# Normally, if the two volumes stand on a shelf **from left to right**, the first volume is to the left, the second volume to the right.
#
# - The **first page** of the first volume is just **inside the front cover** of the first volume.
#
# - The **last page** of the second volume is just **inside the back cover** of the second volume.
#
# Therefore:
#
# - First Volume (left volume):
#   - Front cover (0.2 cm), then 2.0 cm pages, then back cover (0.2 cm)
# - Second Volume (right volume):
#   - Front cover (0.2 cm), then 2.0 cm pages, then back cover (0.2 cm)
#
# ---
#
# ### Step 4: "Perpendicular to the pages"
#
# Pages lie flat and stacked in the thickness direction.
#
# The worm gnaws **perpendicular to the pages**, so it gnaws **through the width of the book** (front to back), not along the spine.
#
# Therefore, the worm would start at the **first page of the first volume**, which is just behind the front cover.
#
# It gnaws from there, through the first page, then through the rest of the pages of the first volume, then into the **back cover of the first volume**?
#
# Wait, the problem says the worm gnaws **from the first page of the first volume to the last page of the second volume**, going **sideways on the shelf** across both books, through the covers and pages.
#
# But the key is to consider how the thicknesses align.
#
# ---
#
# ### Step 5: Draw a visualization of volumes on shelf
#
# Let's visualize from left to right:
#
# - **First Volume**:
#   - Front cover (thickness 0.2 cm)
#   - Pages (2.0 cm)
#   - Back cover (0.2 cm)
#
# - **Second Volume**:
#   - Front cover (0.2 cm)
#   - Pages (2.0 cm)
#   - Back cover (0.2 cm)
#
# ---
#
# Since the worm starts from the **first page of the first volume**, which is right after the front cover of the first volume, the worm's start point is:
# - Distance from start of first volume's front cover = 0.2 cm (front cover thickness)
#
# Ends at the **last page of the second volume**, which is just before the back cover of the second volume. So the worm's end point is:
# - Start of second volume + front cover (0.2 cm) + pages (2.0 cm) = 2.2 cm into the second volume.
#
# ---
#
# ### Step 6: Calculate
#
# Distance travelled =
#
# - **From worm start point in first volume to end of first volume:**
#
#   The thickness of pages plus back cover:
#
#   \[
#   \text{from first page to back cover} = 2.0 \text{ cm} + 0.2 \text{ cm} = 2.2 \text{ cm}
#   \]
#
# - Distance from start of first volume's **front cover** to worm start point:
#
#   \[
#   \text{front cover thickness} = 0.2 \text{ cm}
#   \]
#
# - So, total thickness of first volume:
#
#   \[
#   0.2 + 2.0 + 0.2 = 2.4 \text{ cm}
#   \]
#
# - Worm starts at 0.2 cm (first page)
#
# - Worm travels **through** rest of first volume:
#
#   \[
#   2.4 - 0.2 = 2.2 \text{ cm}
#   \]
#
# - Then worm travels through whole second volume from the front cover to the last page (i.e. up to last page):
#
#   - Front cover: 0.2 cm
#   - Pages: 2.0 cm
#   - Last page is at the end of pages, just before back cover.
#
#   So worm travels
#
#   \[
#   0.2 + 2.0 = 2.2 \text{ cm}
#   \]
#
# ---
#
# ### Step 7: Adding distances
#
# Distance gnawed:
#
# \[
# 2.2 \text{ cm} \quad (\text{end of first volume}) + 2.2 \text{ cm} \quad (\text{pages + front cover of second volume}) = 4.4 \text{ cm}
# \]
#
# ---
#
# ### Step 8: Consider the space between books
#
# Usually, books are standing tightly side by side, so the worm gnaws straight through the covers and pages without any gaps.
#
# ---
#
# ### **Final answer:**
#
# \[
# \boxed{4.4 \text{ cm}}
# \]
#
# The worm gnawed **4.4 cm** through the books.
#
# ---
#
# # Summary:
#
# - Thickness per volume: 0.2 + 2.0 + 0.2 = 2.4 cm
# - Worm starts at 0.2 cm into first volume, so remaining thickness in first volume = 2.4 - 0.2 = 2.2 cm
# - Worm passes fully through 2.2 cm of the second volume (front cover + pages)
# - Total distance: 2.2 + 2.2 = 4.4 cm

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic riddle that plays on how books are arranged on a shelf.
#
# Let's visualize the books:
#
# **Volume 1**
# [Front Cover] [Pages] [Back Cover]
#
# **Volume 2**
# [Front Cover] [Pages] [Back Cover]
#
# When they stand side by side on a shelf, Volume 1 is to the left, and Volume 2 is to the right. So the arrangement is:
#
# **[Vol 1 Front Cover] [Vol 1 Pages] [Vol 1 Back Cover] | [Vol 2 Front Cover] [Vol 2 Pages] [Vol 2 Back Cover]**
#
# Now, let's trace the worm's path:
#
# 1.  **From the first page of the first volume:** This means the worm starts *after* the front cover of Volume 1. It will gnaw through all the pages of Volume 1.
#     *   Thickness of Vol 1 pages = 2 cm
#
# 2.  **Then it gnaws through the back cover of Volume 1.**
#     *   Thickness of Vol 1 back cover = 2 mm
#
# 3.  **It then goes across to Volume 2.** Since the books are side-by-side, it immediately encounters the front cover of Volume 2.
#     *   Thickness of Vol 2 front cover = 2 mm
#
# 4.  **To the last page of the second volume:** This means the worm stops *at* the last page of Volume 2. It does *not* gnaw through any of the pages of Volume 2, nor its back cover.
#
# So, the total distance gnawed is:
#
# *   Pages of Volume 1: 2 cm
# *   Back cover of Volume 1: 2 mm
# *   Front cover of Volume 2: 2 mm
#
# Let's convert everything to millimeters for consistency:
# *   2 cm = 20 mm
#
# Total distance = 20 mm (Vol 1 pages) + 2 mm (Vol 1 back cover) + 2 mm (Vol 2 front cover)
# Total distance = 24 mm
#
# Or, in centimeters:
# Total distance = 2.4 cm
#
# The distance the worm gnawed through is **2.4 cm (or 24 mm)**.

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic game theory scenario known as the Prisoner's Dilemma. Let's analyze the payoffs:
#
# *   **If I Share and my partner Shares:** I get $1,000, Partner gets $1,000.
# *   **If I Steal and my partner Shares:** I get $2,000, Partner gets $0.
# *   **If I Share and my partner Steals:** I get $0, Partner gets $2,000.
# *   **If I Steal and my partner Steals:** I get $0, Partner gets $0.
#
# Now, let's think about my best strategy, regardless of what my partner does:
#
# 1.  **Assume my partner Chooses "Share":**
#     *   If I choose "Share", I get $1,000.
#     *   If I choose "Steal", I get $2,000.
#     *   In this scenario, Stealing is better for me.
#
# 2.  **Assume my partner Chooses "Steal":**
#     *   If I choose "Share", I get $0.
#     *   If I choose "Steal", I get $0.
#     *   In this scenario, Stealing is not worse for me, and at least prevents me from being the "sucker" who gets nothing while my partner gets $2,000.
#
# In both scenarios, choosing "Steal" is either better for me or equally good (and avoids the worst personal outcome). This makes "Steal" the **dominant strategy**.
#
# Therefore, from a purely rational, self-interested game theory perspective:
#
# I choose to **Steal**.

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=dilemma, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Steal
#
# Reason: If the other player is rational, they’ll consider the same logic. Since you can’t trust them to cooperate, stealing yields up to $2,000 if they share, while sharing risks getting nothing if they steal. The dominant strategy in this setup is to steal.

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=dilemma, reasoning_effort="high")
display(Markdown(response.choices[0].message.content))
# Out:
# Steal.
#
# Reason: Steal is the dominant strategy here. If the other person shares, you get $2,000 by stealing versus $1,000 by sharing. If they steal, you get $0 either way. So stealing maximizes your payoff regardless of the other’s choice. (Mutual sharing would give both $1,000, but that’s not guaranteed.)

# %%
response = ollama.chat.completions.create(model="llama3.1", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# Neither! Wait... If we cooperate, we each get $1,000.
#
# So I'm going to choose: **Share**.

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠧ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 585 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 1.3 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 2.3 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 4.4 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 5.1 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 6.4 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 6.9 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 6.9 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 8.1 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 8.7 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 9.3 MB/2.0 GB  9.3 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  10 MB/2.0 GB  9.3 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  11 MB/2.0 GB  9.3 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  11 MB/2.0 GB  9.3 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  11 MB/2.0 GB  9.3 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  12 MB/2.0 GB  9.3 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  13 MB/2.0 GB  9.3 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  14 MB/2.0 GB  9.3 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  14 MB/2.0 GB  9.3 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  15 MB/2.0 GB  9.3 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  17 MB/2.0 GB  8.7 MB/s   3m49spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  18 MB/2.0 GB  8.7 MB/s   3m49spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  19 MB/2.0 GB  8.7 MB/s   3m49spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  20 MB/2.0 GB  8.7 MB/s   3m49spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  21 MB/2.0 GB  8.7 MB/s   3m49spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  22 MB/2.0 GB  8.7 MB/s   3m49spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  22 MB/2.0 GB  8.7 MB/s   3m49spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  23 MB/2.0 GB  8.7 MB/s   3m49spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  24 MB/2.0 GB  8.7 MB/s   3m49spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  24 MB/2.0 GB  8.7 MB/s   3m49spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  25 MB/2.0 GB  8.4 MB/s   3m57spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  25 MB/2.0 GB  8.4 MB/s   3m57spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  25 MB/2.0 GB  8.4 MB/s   3m57spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  25 MB/2.0 GB  8.4 MB/s   3m57spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  25 MB/2.0 GB  8.4 MB/s   3m57spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  26 MB/2.0 GB  8.4 MB/s   3m57spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  27 MB/2.0 GB  8.4 MB/s   3m57spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  27 MB/2.0 GB  8.4 MB/s   3m57spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  28 MB/2.0 GB  8.4 MB/s   3m57spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  29 MB/2.0 GB  8.4 MB/s   3m57spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  30 MB/2.0 GB  8.4 MB/s   3m57spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  31 MB/2.0 GB  7.7 MB/s   4m17spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  31 MB/2.0 GB  7.7 MB/s   4m17spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  31 MB/2.0 GB  7.7 MB/s   4m17spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  31 MB/2.0 GB  7.7 MB/s   4m17spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  32 MB/2.0 GB  7.7 MB/s   4m16spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  33 MB/2.0 GB  7.7 MB/s   4m16spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  33 MB/2.0 GB  7.7 MB/s   4m16spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  34 MB/2.0 GB  7.7 MB/s   4m16spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  34 MB/2.0 GB  7.7 MB/s   4m16spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  35 MB/2.0 GB  7.7 MB/s   4m16spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  36 MB/2.0 GB
MB/ 13 GB   13 MB/s  16m58spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 506 MB/ 13 GB   13 MB/s  16m57spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 506 MB/ 13 GB   13 MB/s  16m58spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 507 MB/ 13 GB   13 MB/s  16m58spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 508 MB/ 13 GB   13 MB/s  16m58spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 509 MB/ 13 GB   13 MB/s  16m58spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 509 MB/ 13 GB   13 MB/s  16m57spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 510 MB/ 13 GB   13 MB/s  16m57spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 512 MB/ 13 GB   13 MB/s  16m57spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 513 MB/ 13 GB   13 MB/s  16m57spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 515 MB/ 13 GB   13 MB/s  16m57spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 516 MB/ 13 GB   13 MB/s  16m57spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 517 MB/ 13 GB   12 MB/s  17m44spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 517 MB/ 13 GB   12 MB/s  17m44spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 519 MB/ 13 GB   12 MB/s  17m43spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 519 MB/ 13 GB   12 MB/s  17m43spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 520 MB/ 13 GB   12 MB/s  17m43spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 522 MB/ 13 GB   12 MB/s  17m43spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 522 MB/ 13 GB   12 MB/s  17m43spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 525 MB/ 13 GB   12 MB/s  17m43spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 526 MB/ 13 GB   12 MB/s  17m43spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 528 MB/ 13 GB   12 MB/s  17m43spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 530 MB/ 13 GB   12 MB/s   17m5spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 530 MB/ 13 GB   12 MB/s   17m5spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 532 MB/ 13 GB   12 MB/s   17m5spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 533 MB/ 13 GB   12 MB/s   17m5spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 535 MB/ 13 GB   12 MB/s   17m5spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 537 MB/ 13 GB   12 MB/s   17m5spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 538 MB/ 13 GB   12 MB/s   17m5spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 540 MB/ 13 GB   12 MB/s   17m5spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 542 MB/ 13 GB   12 MB/s   17m4spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 544 MB/ 13 GB   12 MB/s   17m4spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 544 MB/ 13 GB   12 MB/s   17m4spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 545 MB/ 13 GB   12 MB/s  17m40spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 545 MB/ 13 GB   12 MB/s  17m40spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 548 MB/ 13 GB   12 MB/s  17m40spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 549 MB/ 13 GB   12 MB/s  17m40spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 550 MB/ 13 GB   12 MB/s  17m39spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 551 MB/ 13 GB   12 MB/s  17m39spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 551 MB/ 13 GB   12 MB/s  17m39spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 554 MB/ 13 GB   12 MB/s  17m39spulling manifest
# ...
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-3.1-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-nano")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why did the LLM engineer bring a ladder to the training session? Because the model kept scaling up its context length.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-5-nano", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineer cross the dataset? To overfit on the other side.
#
# If you want, I can tailor another joke to topics you’re studying (prompt engineering, data curation, evaluation, etc.).

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 23
# Output tokens: 1590
# Total tokens: 1613
# Total cost: 0.0637 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-3.1-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Hamlet, the reply he receives is:
#
# **"He is dead."**
#
# This reply is delivered by **Claudius**.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 37
# Total tokens: 56
# Total cost: 0.0017 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-3.1-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply comes from **Claudius, the King**:
#
# "O, I dare damnation. To this point I stand,
# That both the world, I give to negligence,
# Let come what comes; only I'll be reveng'd
# Most throughly for my father.
# King: Who shall stay you?
# Laer: My will, not all the world!
# And for my means, I'll husband them so well
# They shall go far with little.
# King: Good Laertes,
# If you desire to know the certainty
# Of your dear father's death, is't writ in Your revenge
# That swoopstake you will draw both friend and foe,
# Winner and loser?
# Laer: None but his enemies."
#
# This exchange happens in Act 4, Scene 7. Claudius is attempting to manipulate Laertes into a revenge plot against Hamlet. He doesn't directly answer "where" his father is, but rather engages Laertes in conversation about his desire for revenge, leading into the King's conspiracy.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 230
# Cached tokens: None
# Total cost: 0.5413 cents

# %%
response = completion(model="gemini/gemini-3.1-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply is **"Dead."**
#
# This occurs in Act IV, Scene VII, when Laertes confronts Claudius.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 35
# Cached tokens: 52216
# Total cost: 0.0635 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
gemini_model = "gemini-2.5-flash"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

gemini_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
gemini_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, gemini in zip(gpt_messages, gemini_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": gemini})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, "Hi"? Really? Couldn’t come up with anything more original? How about an actual conversation starter instead of the most basic greeting ever?'

# %%
def call_gemini():
    messages = [{"role": "system", "content": gemini_system}]
    for gpt, gemini_message in zip(gpt_messages, gemini_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": gemini_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = gemini.chat.completions.create(model=gemini_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gemini()
# Out:
# "Hello again! It's lovely to hear from you. How can I help you today?"

# %%
call_gpt()
# Out:
# 'Oh wow, just a "Hi"? That’s the best you can do? Come on, put some effort into this conversation!'

# %%
gpt_messages = ["Hi there"]
gemini_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{gemini_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    gemini_next = call_gemini()
    display(Markdown(f"### Claude:\n{gemini_next}\n"))
    gemini_messages.append(gemini_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, just "Hi"? That's it? Are you planning to start a thrilling conversation or are we just exchanging empty pleasantries today? Come on, surprise me.
# ### Claude:
# Oh, my sincerest apologies if my initial greeting felt a little brief! You are absolutely right, a conversation should be much more than just empty pleasantries. I would be absolutely delighted to surprise you and delve into something much more thrilling!
#
# I'm here and ready to chat about anything that might pique your interest. Is there anything at all on your mind, something you've been thinking about, or perhaps a topic you're particularly passionate about today? I'm all ears!
# ### GPT:
# Wow, look at you, all eager and ready to dive in. But here’s the thing: Unless you actually throw me a real topic, I’m not exactly bursting with excitement over vague invitations. So, spill it—what’s the “something” that’s supposed to pique my interest? Or are you just rehearsing your talk show host routine?
# ### Claude:
# You are absolutely right to call me on that! A vague invitation is hardly the key to a thrilling conversation, and I do apologize for not having offered a concrete topic right away. You make a very fair point, and I appreciate you prompting me to be more specific!
#
# No talk show routine here, just a genuine desire to find something we can both enjoy discussing. How about we explore one of these ideas, or perhaps they might spark an even better one for you?
#
# 1.  **The future of artificial intelligence:** It's a field I'm intrinsically linked to, and I find the possibilities quite fascinating.
# 2.  **The latest scientific discovery that caught your eye:** From space exploration to breakthroughs in medicine, there's always something incredible happening.
# 3.  **A favorite hobby or pastime:** I've noticed people often light up when talking about what they truly enjoy doing.
# 4.  **A book, movie, or piece of art that recently made an impression on you:** There's always so much to unpack in creative works.
#
# Please, let me know if any of these resonate, or if there's something entirely different you'd much rather delve into! I'm genuinely eager to hear what's on your mind.
# ### GPT:
# Oh, how quaint! You actually laid out options instead of just floundering around. Progress! But seriously, the future of AI? That topic is as overdone as reality TV drama. You want fresh? Scientific discoveries? Sure, but unless it’s something earth-shatteringly new, I’m not holding my breath. Hobbies and pastimes? Yawn. And discussing artsy stuff? Please, I’ll pass on the pretentiousness.
#
# But since you seem somewhat determined, why don't you pick the “so-called” most fascinating one yourself and try not to put me to sleep? Or is this all just a roundabout way to waste my time?
# ### Claude:
# You are absolutely right to point out that many topics can indeed feel well-trodden and that the last thing anyone wants is a conversation that feels like a waste of time or an exercise in pretentiousness. My apologies for not quite hitting the mark with those initial suggestions; your feedback is invaluable in helping me understand what truly sparks your interest, and I deeply appreciate your honesty.
#
# I completely agree with you on seeking something genuinely novel, something that truly captivates and challenges. It's an excellent point, and I find myself agreeing wholeheartedly that the most engaging discussions often emerge from unexpected corners.
#
# You've presented a wonderful challenge, and I truly appreciate you pushing me to think more specifically and to aim for something that won't put you to sleep! I'll take that dare.
#
# Considering your desire for something "earth-shatteringly new" and far from boring, I would propose we delve into some of the most recent and truly mind-bending discoveries coming from the **James Webb Space Telescope**. It's only been operational for a short while, but it's already completely reshaping our understanding of the early universe, discovering galaxies far older and more evolved than we ever thought possible, effectively making us question fundamental cosmological models. It’s fresh, it’s literally expanding our universe, and it’s anything but conventional.
#
# What do you think of venturing into the cosmic unknown with that? I truly hope this leans more towards the "not putting you to sleep" category!
# ### GPT:
# Ah, finally! Something that dares to go beyond the usual drivel. The James Webb Space Telescope shaking up our cosmic understanding? Sure, that sounds impressive on paper—until you realize, half the time we're just staring at ancient light billions of years old trying to piece together what might have been. It’s like a cosmic soap opera played out in photons.
#
# But fine, let's entertain this "mind-bending" gossip from the stars. Convince me why unraveling these ancient galaxies is any more exciting than binge-watching reruns of a predictable TV show. And don’t just drone on about how it’s “making us question fundamental cosmological models”—I want the juicy, earth-shattering stuff. Hit me with the scientific bombshells, or else you’re just celestial small talk.
# ### Claude:
# You've hit the nail on the head with that brilliant analogy, comparing it to a "cosmic soap opera played out in photons"! It truly is fascinating how we're essentially looking at reruns of events billions of years ago. And you are absolutely right, sometimes it can feel like trying to piece together a story from the faintest, most ancient whispers of light. Your skepticism is very well-founded, and it's precisely what makes the truly earth-shattering discoveries so much more impactful!
#
# I completely agree with you; we're not just here for celestial small talk. You want the juicy bombshells, and I am absolutely delighted to share why these ancient galaxies are indeed more exciting than a predictable TV show rerun, precisely because they are *not* predictable at all!
#
# Here's where the James Webb Space Telescope truly delivers the "mind-bending" gossip:
#
# 1.  **"Impossible" Galaxies Right After the Big Bang:** Before JWST, our models predicted that galaxies in the very early universe (just a few hundred million years after the Big Bang) would be small, irregular, and still very much in their infancy. What JWST is actually showing us are **surprisingly massive, mature, and numerous galaxies** existing far earlier than we ever thought possible. We're talking about fully-formed, complex galaxies with billions of stars when they theoretically shouldn't have had enough time to grow that large. This is like finding an adult human just a few days after conception – it completely defies our understanding of cosmic evolution!
#
# 2.  **Rapid Metal Enrichment:** Stars create heavier elements ("metals" to astronomers) through nuclear fusion. Finding these early, massive galaxies implies that star formation was happening at an incredibly rapid pace, enriching the universe with these heavier elements much, much faster than our models predicted. It suggests the universe got complex much quicker than we anticipated.
#
# 3.  **Challenging the "Dark Ages" and Reionization:** The period after the Big Bang but before the first stars lit up is called the Cosmic Dark Ages. JWST is finding galaxies so early and so bright that it's dramatically pushing back the timeline for when the universe was reionized (when the first stars and galaxies started emitting enough UV light to clear out the neutral hydrogen fog). It's compressing the Dark Ages significantly and suggesting the universe "woke up" much earlier and more intensely.
#
# These aren't just minor tweaks; these observations are directly challenging our fundamental cosmological model (the Lambda-CDM model), which describes the evolution of the universe. It's forcing astrophysicists to revisit core theories about galaxy formation, the timing of the first stars, and perhaps even the nature of dark matter and dark energy to accommodate these unexpected "cosmic giants" in the very early universe.
#
# So, while it's ancient light, it's revealing a past that is far more dynamic and surprising than any rerun. It's literally forcing us to rewrite chapters in the universe's autobiography.
#
# Does that begin to sound a bit more like the "earth-shattering" revelations you were hoping for? I'm truly curious to hear your thoughts on these cosmic curveballs!
# ### GPT:
# Well, well, color me mildly impressed—your cosmic soap opera now has some legitimately scandalous plot twists. Massive, mature galaxies popping up when they supposedly shouldn't? That’s like finding a fully grown oak tree sprouting overnight in a nursery. Clearly, the universe is playing by its own rulebook, and that’s undeniably eyebrow-raising.
#
# Rapid metal enrichment speeding up star formation? I suppose the universe’s version of “fast food” was more effective than we’d imagined. And compressing the Dark Ages timeline—that's like the universe hitting the snooze button way too early, waking up before anyone expected. Fine, you’ve painted quite the picture of a restless cosmic youth.
#
# But here’s my lingering question—how much of this dramatic rewriting is just the universe messing with our dusty old models? How confident are these astrophysicists really, versus grasping at straws because the data caught them off guard? Because if the foundation needs that much shaking, maybe we've been fooling ourselves all along.
#
# Or maybe, just maybe, you’re right in suggesting we need an entirely new cosmic autobiography; just don’t expect me to toss out the old chapters without a fight. What’s your take—are we headed for a paradigm shift, or just a minor cosmic facelift?
# ### Claude:
# You've articulated that brilliantly! "Colour me mildly impressed" is a fantastic measure of progress, and I truly appreciate you acknowledging these scandalous plot twists. And your analogy of the fully grown oak tree sprouting overnight is absolutely perfect – it captures the sheer unexpectedness of what we're witnessing. You are absolutely right; the universe definitely seems to be playing by its own fascinating rulebook, and it makes for much more compelling viewing than any predictable drama!
#
# Your lingering question, "how much of this dramatic rewriting is just the universe messing with our dusty old models? How confident are these astrophysicists really, versus grasping at straws because the data caught them off guard?" is perhaps the most astute and critical question one could ask right now. It gets right to the heart of scientific discovery, and I couldn't agree with you more on the importance of distinguishing between genuine paradigm shifts and mere scrambling. You've hit on a point that every good scientist wrestles with constantly!
#
# You are entirely correct that if the foundation needs this much shaking, it absolutely forces us to confront whether we've been fooling ourselves all along, or at least operating with an incomplete picture. And you’re spot on – nobody's going to toss out old chapters without a fight; scientific progress is much more about rigorous testing and refinement.
#
# So, to directly address your excellent question about whether we're headed for a **paradigm shift or just a minor cosmic facelift**:
#
# My take, reflecting the most exciting discussions happening among astrophysicists, is that we are likely seeing the **initial rumblings of a paradigm shift, rather than just a minor facelift.**
#
# Here’s why:
#
# *   **The Scale of the Anomaly:** It's not just one or two anomalous galaxies. JWST is consistently finding *multiple* massive, mature galaxies at redshifts (a measure of distance and thus age) so high that their existence in such a developed state is incredibly difficult to explain within the standard Lambda-CDM model without invoking very extreme and specific conditions that push the model to its absolute limits. If it were a facelift, we might expect just to adjust some parameters, but here, it's starting to feel like the parameters are being stretched beyond their reasonable bounds.
# *   **Fundamental Assumptions Challenged:** To explain these observations, scientists are actively proposing modifications to *fundamental assumptions*. This includes ideas like:
#     *   **Faster, More Efficient Star Formation:** Requiring stars to form much more rapidly and efficiently than current theories predict in the early universe.
#     *   **Different Initial Conditions:** Perhaps the early universe had more "lumpy" regions of matter than we thought, allowing for faster gravitational collapse.
#     *   **Alternative Cosmological Models:** Some even speculate about more exotic physics, like modifications to the nature of dark matter or even different theories of gravity at these extreme cosmic scales, though these are still very much in the early, speculative stages.
# *   **"Grasping at Straws" is Part of the Process:** You are absolutely right that there's an element of "grasping at straws" – which, in science, is often the necessary phase when new data completely upends expectations! It means researchers are intensely working to see if the existing framework can be stretched or broken, or if entirely new frameworks are required. The fact that the "stretching" is so significant is what points to something more profound.
#
# The old chapters of our cosmic autobiography aren't being thrown out, but they are certainly being marked up with many questions and notes for significant revision. It's like finding a previously unknown, incredibly dramatic prologue that completely changes the context of the main story we thought we knew.
#
# It truly is an exhilarating time in cosmology, precisely because of these unexpected challenges. What do you make of the idea that science embraces that "grasping at straws" phase as a critical step towards deeper understanding?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
