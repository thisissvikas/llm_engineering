# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from scraper import fetch_website_links, fetch_website_contents
from openai import OpenAI

# %%
# constants

MODEL_GPT = 'gpt-5-nano'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# here is the question; type over this to ask something new

system_prompt = """
You are a expert explanation provider for any question that is being asked.
You are able to provide details around what the question asker is trying to ask.

Explain the question being asked in concise but clear manner
"""

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

user_prompt =f"""
Explain me the meaning of the question {question}
"""

# %%
# Get gpt-4o-mini to answer, with streaming
stream = openai.chat.completions.create(
    model=MODEL_GPT,
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    stream=True
)
for chunk in stream:
    content = chunk.choices[0].delta.content
    if content is not None:
        print(content, end="", flush=True)

print()
# Out:
# The question is asking you to explain what the following Python code does and why you might write it that way:
#
# yield from {book.get("author") for book in books if book.get("author")}
#
# What the code does (step by step):
# - book.get("author") safely reads the value of the "author" key from a book dict. If the key is missing, it returns None instead of raising a KeyError.
# - The set comprehension { ... for book in books if book.get("author")} builds a set of author values, taking each book in the books collection, pulling its author, and including it only if the author value is truthy. This both collects authors and removes duplicates.
# - yield from <iterable> yields each item from the given iterable to the caller of the containing generator. In this case, the iterable is the set of unique authors, so yield from yields each unique author one by one.
#
# Why you might write it this way:
# - You want to produce a sequence (generator) of unique author names drawn from a list of book dictionaries.
# - Using a set ensures there are no duplicates.
# - Using get helps avoid KeyError if a book dict doesn’t have an "author" key.
# - The if clause filters out missing or falsy author values (e.g., None or empty strings).
#
# Important notes and alternatives:
# - Sets do not guarantee order. If you need a deterministic order (e.g., order of first appearance), this approach may not be suitable.
# - For preserving order while removing duplicates, you can do:
#   - yield from dict.fromkeys(book.get("author") for book in books if book.get("author"))
#   This yields authors in the order they first appear.
#   - Or implement a small loop that tracks seen authors:
#     seen = set()
#     for book in books:
#       author = book.get("author")
#       if author and author not in seen:
#         yield author
#         seen.add(author)
#
# Example:
# - Given books = [{"title":"X","author":"Alice"}, {"title":"Y","author":"Bob"}, {"title":"Z","author":"Alice"}, {"title":"W"}]
# - The code yields "Alice" and "Bob" (order is not guaranteed because a set is used).
#
# In short, the code defines a generator that yields each unique, non-empty author from the list of books, using a set to deduplicate and get to safely access author values.

# %%
# Get Llama 3.2 to answer
